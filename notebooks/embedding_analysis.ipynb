# %% [markdown]
# # B-JEPA Embedding Analysis
#
# Load a checkpoint and explore the learned representations.

# %%
from bdna_jepa import load_encoder
# encoder = load_encoder('outputs/checkpoints/v4.0/best.pt', version='v4.0')
